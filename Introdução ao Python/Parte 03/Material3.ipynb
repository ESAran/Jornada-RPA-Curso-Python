# %% [markdown]
# ![toporpa.png](data:image/png;base64,...)

# %% [markdown]
# # 💻 MÓDULO 01 | INTRO: LINGUAGEM DE PROGRAMAÇÃO PYTHON | PARTE 03
# ---
#
# > *Este material foi revisado e estruturado didaticamente para a capacitação Jornada RPA da DB Assessoria em Sistemas de Informação.
# O objetivo geral é guiar a introdução na (ou revisão da) Linguagem de Programação Python para que possamos seguir compreender exemplos e construir práticas de automação robótica de processos.*
# >
# &nbsp;
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**Este é a PARTE 3 que irá cobrir os seguintes conteúdos:**
#
# - INTERAÇÃO COM ARQUIVOS: interação com diferentes tipos de arquivos, arquivos texto, arquivos em formato CSV e em formato JSON.
#
# - MANIPULAÇÃO DE DADOS: manipulação de dados com biblioteca Pandas.

# %% [markdown]
# ## 📄 ARQUIVOS DE TEXTO
# ------

# %% [markdown]
# Existem diferentes modos de abertura de arquivos:
#
# "r" - read: é o valor padrão, abre o arquivo para leitura e apresenta erro se o arquivo não existir.
#
# "a" - append - abre o arquivo para adicionar conteúdo e cria um novo se o arquivo não existir.
#
# "w" - write - abre o arquivo para escrita, sobrescreve se o arquivo já existir e criar um novo se o arquivo não existir.
#
# "x" - create - cria um arquivo específico e retorna um erro caso o arquivo já existir.
#
# Podemos também definir se estamos lidando com um arquivo de texto ou arquivo binário.
#
# "t" - text: é o valor padrão, modo de texto.
#
# "b" - binary: modo binário, por exemplo: images, arquivos PDF e etc.

# %%
with open("arquivo.txt", "w") as arq:
    arq.write("Estamos escrevendo a primeira linha do arquivo\n")
    arq.write("Vejam só, esta é a segunda linha do arquivo\n")
    arq.close()

# %%
arq = open("arquivo.txt", "r")

# leitura de uma linha do arquivo
# print(arq.readline())

# leitura de todas as linhas do arquivo e coloca em uma lista
print(arq.readlines())
arq.close()
# Out:
# ['Estamos escrevendo a primeira linha do arquivo\n', 'Vejam só, esta é a segunda linha do arquivo\n', 'Este é um terceiro conteúdo\n', 'Este é o quarto conteúdo\n']

# %%
with open("arquivo.txt", "a") as arq:
    arq.writelines(["Este é um terceiro conteúdo\n", "Este é o quarto conteúdo\n"])

# %%
print("Nome: " + arq.name)
print("Modo: " + arq.mode)
print("Tipo: " + str(type(arq)))
# Out:
# Nome: arquivo.txt
# Modo: r
# Tipo: <class '_io.TextIOWrapper'>

# %%
arq = open("arquivo.txt", "r")
# indica o ponto onde o cursor de movimentação do arquivo se encontra
print("Está em: %s" % arq.tell())
print(arq.readlines())
print("Está em: %s" % arq.tell())
arq.seek(0)
print("Está em: %s" % arq.tell())
# Out:
# Está em: 0
# ['Estamos escrevendo a primeira linha do arquivo\n', 'Vejam só, esta é a segunda linha do arquivo\n', 'Este é um terceiro conteúdo\n', 'Este é o quarto conteúdo\n']
# Está em: 150
# Está em: 0

# %%
with open("arquivo.txt", "r") as arq:
    # delimita a quantidade de caracteres a serem lidos
    print(arq.read(4))
    print(arq.tell())
    print(arq.read(6))
# Out:
# Esta
# 4
# mos es

# %%
with open("arquivo.txt", "r") as arq:
    linhas = arq.readlines()
    for linha in linhas:
        print(linha)
# Out:
# Estamos escrevendo a primeira linha do arquivo
#
# Vejam só, esta é a segunda linha do arquivo
#
# Este é um terceiro conteúdo
#
# Este é o quarto conteúdo

# %% [markdown]
# ## 🗃️ ARQUIVOS CSV
# -------

# %%
import csv

arqcsv = "filmes.csv"
lista = []

with open(arqcsv, "r") as arq:
    formato_csv = csv.reader(arq)
    for linha in formato_csv:
        lista.append(linha)
    #for linha in formato_csv:
    #   print(linha[0])
    # acessando a linha 100 do arquivo, mas terceiro elemento (gêneros)
    # print(lista[100][2])
# Out:
# 0

# %%
print(lista)
# Out:
# [['id', 'titulo', 'generos'], ['1', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantasy'], ['2', 'Jumanji (1995)', 'Adventure|Children|Fantasy'], ['3', 'Grumpier Old Men (1995)', 'Comedy|Romance'], ['4', 'Waiting to Exhale (1995)', 'Comedy|Drama|Romance'], ['5', 'Father of the Bride Part II (1995)', 'Comedy'], ['6', 'Heat (1995)', 'Action|Crime|Thriller'], ['7', 'Sabrina (1995)', 'Comedy|Romance'], ['8', 'Tom and Huck (1995)', 'Adventure|Children'], ['9', 'Sudden Death (1995)', 'Action'], ['10', 'GoldenEye (1995)', 'Action|Adventure|Thriller'], ['11', 'American President, The (1995)', 'Comedy|Drama|Romance'], ['12', 'Dracula: Dead and Loving It (1995)', 'Comedy|Horror'], ['13', 'Balto (1995)', 'Adventure|Animation|Children'], ['14', 'Nixon (1995)', 'Drama'], ['15', 'Cutthroat Island (1995)', 'Action|Adventure|Romance'], ['16', 'Casino (1995)', 'Crime|Drama'], ['17', 'Sense and Sensibility (1995)', 'Drama|Romance'], ['18', 'Four Rooms (1995)', 'Comedy'], ['19', 'Ace Ventu
# ...

# %%
with open("novo_arquivo.csv", "w") as arq_novo:
    novo = csv.writer(arq_novo, delimiter="\t")
    novo.writerows(lista)

# %%
# Descobrir o delimitador do arquivo em formato CSV

with open("novo_arquivo.csv", "r") as arq_novo:
#with open("filmes.csv", "r") as arq_novo:
    dialect = csv.Sniffer().sniff(arq_novo.read(1024))
    print("* " + dialect.delimiter + " *")
# Out:
# * 	 *

# %% [markdown]
# ## 💡 ARQUIVOS JSON
# ----

# %% [markdown]
# Importação do arquivo JSON para List

# %%
import json

with open("filmes.json", "r") as arq_json:
    dados = json.load(arq_json)
    print(dados)

for linha in dados:
    print(linha["titulo"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-8323e9b5f4b9> in <cell line: 3>()
#       1 import json
#       2
# ----> 3 with open("https://alinedecampos.pro.br/etc/datasets/filmes.json", "r") as arq_json:
#       4     dados = json.load(arq_json)
#       5     print(dados)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://alinedecampos.pro.br/etc/datasets/filmes.json'

# %% [markdown]
# # 🐼 &nbsp; BIBLIOTECA PANDAS
# ---

# %% [markdown]
# ### 📢&nbsp;&nbsp;INTRODUÇÃO

# %% [markdown]
# A biblioteca [Pandas](https://pandas.pydata.org/) é amplamente utilizada para se trabalhar com grandes datasets em análise de dados e tem como base a Linguagem de Programação Python. Apresenta funcionalidades de análise, pré-processamento, exploração e manipulação dse dados. O nome "Pandas" vem de "Panel Data" e "Python Data Analysis" e foi criado por Wes McKinney em 2008.
#
# Tem uma ótima performance no trabalho com dados usando o objeto DataFrame que se trata de uma estrutura de dados tabular, orientada a colunas, com rótulos (labels) tanto para linhas quanto para colunas e também com arrays unidimensionais chamados com o objeto Series.
#
# Usando o processamento de alto desempenho de arrays da biblioteca [NumPy](https://numpy.org/) com recursos bastantes flexíveis para manipulação de dados tanto de planilhas, quanto em banco de dados relacionais. A biblioteca permite analisar grandes quantidades de dados e gerar conclusões baseadas em teorias estatísticas. Além disso pode realizar um ótimo apoio nas tarefas de pré-processamento dos dados, tais como a detecção de valores faltantes, substituição de valores e etc, tornando mais legíveis e relevantes. Além disso,
# podemos trabalhar com processos estatísticos como contagem, média, mediana, moda, valor máximo, valor mínimo, além de correlações.
#
# Para a referência completa da biblioteca Pandas acesse a [documentação oficial](http://pandas.pydata.org/pandas-docs/stable/index.html).
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**Este material didático irá cobrir os seguintes conteúdos:**
#   * Estruturas de dados em `DataFrame` e `Series` da biblioteca *Pandas*
#   * Acesso e manipulação de dados com `DataFrame` e `Series`
#   * Importação de dados de arquivo CSV e manipulação através de `DataFrame`

# %% [markdown]
# ####Importação e utilização

# %% [markdown]
# Para importar a biblioteca Pandas basta chama-la usando a palavra chave `import`.
#
# É recomendável criar um `alias` para chamada da biblioteca, como no exeplo a seguir, estamos nomeando o acesso como `pd`

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# Caso você precise saber qual a versão do Pandas está instalada atualmente, use o comando a seguir:

# %%
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# Para exibir de uma maneira mais legível os dados dos DataFrames, vamos importar também o módulo `display` da biblioteca `IPython`.

# %%
from IPython.display import display

# %% [markdown]
# ### 🎲&nbsp;&nbsp;ESTRUTURAS DE DADOS

# %% [markdown]
# As estruturas de dados primárias no Pandas são implementadas em duas classes:
#
# * **`DataFrame`**: uma estrutura tal qual uma tabela relacional com linhas e colunas.
# * **`Series`**: que contém uma única coluna
#
# Assim, um `DataFrame` contém uma ou mais `Series` e um nome para cada `Series`.
#
# A estrutura de DataFrame é bastante comum na abstração para manipulação de dados e também é implementada em no framework [Spark](https://spark.apache.org/) e na Linguagem [R](https://www.r-project.org/about.html).
#
# Objetos `DataFrame` podem ser criados passando um dicionários mapeando os nomes das colunas para suas respectivas `Series`. Se a `Series` não coincide no tamanho, valores faltantes são preenchidos com [NA/NaN](http://pandas.pydata.org/pandas-docs/stable/missing_data.html).

# %% [markdown]
# #### Séries

# %% [markdown]
# Séries não estruturas unidimensionais que podem ter índices numéricos ou em outros formatos.

# %% [markdown]
# Podemos usar a estrutura de dados `Series` passando os valores em uma lista.
# O segundo parâmetro `index` indica qual deve ser o identificar de índice para cada elemento. Caso não seja designados valores para o índice, os valores serão números em ordem crescente iniciando por 0.

# %% [markdown]
# \

# %%
s = pd.Series(["Azul", "Roxo", "Laranja"], index=[0, 2, 4])
display(s)
# Out:
# 0       Azul
# 2       Roxo
# 4    Laranja
# dtype: object

# %% [markdown]
# Para saber a quantidade de valores em uma série usa-se `size`:

# %%
s.size
# Out:
# 3

# %% [markdown]
# Para retornar um array com os valores contidos na série, usa-se `values`:

# %%
s.values
# Out:
# array(['Azul', 'Roxo', 'Laranja'], dtype=object)

# %% [markdown]
# Podemos acessar um valor diretamente pelo seu índice com `at`:

# %%
s[2]
# Out:
# 'Roxo'

# %% [markdown]
# Estrutura para buscar todos `findall`

# %%
s.str.findall("Roxo")
# Out:
# 0        []
# 2    [Roxo]
# 4        []
# dtype: object

# %% [markdown]
# Para exibição da lista, podemos adicionar elementos depois com `add()` e antes com `radd()`. Esses elementos são apenas para visualização.

# %%
s.add("!").radd("#")
# Out:
# 0       #Azul!
# 2       #Roxo!
# 4    #Laranja!
# dtype: object

# %% [markdown]
# Para adicionar novos valores em uma série o recomendado é utilizar a função do pandas `concat`. Ela aceita apenas a concatenação de uma série em outra, portanto deve-se passar como primeiro parâmetro a série atual e como segundo parâmetro a nova série a ser agregada.

# %%
s = pd.concat([s, pd.Series(["Amarelo", "Verde"], index=[6, 8])])

# %%
display(s)
# Out:
# 0       Azul
# 2       Roxo
# 4    Laranja
# 6    Amarelo
# 8      Verde
# dtype: object

# %% [markdown]
# Se não estipularmos os valores de índice, podemos passar como terceiro  parâmetro `ignore_index=True` para que seja estruturada a indexação adequadamente.

# %%
s1 = pd.Series(["Uva", "Maça", "Morango"])
display(s1)

s2 = pd.Series(["Banana", "Morango"])
display(s2)

sn = pd.concat([s1, s2], ignore_index=True)
display(sn)
# Out:
# 0        Uva
# 1       Maça
# 2    Morango
# dtype: object
# 0     Banana
# 1    Morango
# dtype: object
# 0        Uva
# 1       Maça
# 2    Morango
# 3     Banana
# 4    Morango
# dtype: object

# %% [markdown]
# Ao usar `is_unique` avalia se os valores todos são únicos. Neste caso irá retornar `False`, pois temos o valor "morango" repetido.

# %%
sn.is_unique
# Out:
# False

# %% [markdown]
# Para retornar em um array apenas os valores únicos, pode-se usar `unique()`

# %%
sn.unique()
# Out:
# array(['Uva', 'Maça', 'Morango', 'Banana'], dtype=object)

# %% [markdown]
# Podemos reindexar os índices caso seja necessário. Na série `s` temos atualmente os índices 0, 2, 4, 6 e 8, se quisermos reindexar para que a série tenha 10 valores, teremos que definnir quais são os valores faltantes.
#
# Assim, existem opções para o método de completude de dados:
# `ffill`: último valor válido;
# `bfill`: próximo valor válido;
# `nearest`: o valor mais próximos;
#
# Ainda, pode-se estabelecer um valor usando `fill_value` (por exemplo: `fill_value="VAZIO"`)

# %%
s.reindex(range(10), method="nearest") # fill_value="NULL"
# Out:
# 0       Azul
# 1       Roxo
# 2       Roxo
# 3    Laranja
# 4    Laranja
# 5    Amarelo
# 6    Amarelo
# 7      Verde
# 8      Verde
# 9      Verde
# dtype: object

# %% [markdown]
# #### DataFrame

# %% [markdown]
# Um DataFrame é um objeto que representa uma tabela e contém uma coleção ordenada de colunas em que cada uma pode ter um tipo de valor diferente. Possui um índice tanto para linha quanto para coluna, podendo ser imaginado como um dicionário de séries onde todos compartilham o mesmo índice (MCKINNEY, 2018, p. 117).
#
# Para criar um dataframe devemos usar a função `DataFrame` da biblioteca Pandas, passando como parâmetro um dicionário de dados.

# %%
df = pd.DataFrame({"nome": ["Aline", "Pedro", "Marina", "José"],
                   "idade": [39, 35, 28, 45],
                   "pet": ["gato", "cachorro", "papagaio", "peixe"]})

# %%
display(df)
# Out:
#      nome  idade       pet
# 0   Aline     39      gato
# 1   Pedro     35  cachorro
# 2  Marina     28  papagaio
# 3    José     45     peixe

# %% [markdown]
# Para exibir as colunas de um DataFrame usa-se `columns`:

# %%
df.columns
# Out:
# Index(['nome', 'idade', 'pet'], dtype='object')

# %% [markdown]
# Já para exibir valores de um DataFrame usa-se `values`:

# %%
df.values
# Out:
# array([['Aline', 39, 'gato'],
#        ['Pedro', 35, 'cachorro'],
#        ['Marina', 28, 'papagaio'],
#        ['José', 45, 'peixe']], dtype=object)

# %% [markdown]
# Criando um nome para a estrutura de índices do DataFrame com `index.name`:

# %%
df.index.name = "id"
display(df)
# Out:
#       nome  idade       pet
# id
# 0    Aline     39      gato
# 1    Pedro     35  cachorro
# 2   Marina     28  papagaio
# 3     José     45     peixe

# %% [markdown]
# Para inserção de um novo valor no DataFrame, devemos usar a função da biblioteca Pandas `concat` passando como parâmetro outro DataFrame a ser concatenado.

# %%
dados = pd.DataFrame({ "nome": ["Abelino"],
                       "idade":[67],
                       "pet": ["cachorro"] })
pd.concat([df, dados], ignore_index=True)
# Out:
#       nome  idade       pet
# 0    Aline     39      gato
# 1    Pedro     35  cachorro
# 2   Marina     28  papagaio
# 3     José     45     peixe
# 4  Abelino     67  cachorro

# %% [markdown]
# Caso seja necessário realizar a transposição de um DataFrame (as linhas tornam-se colunas e vice-versa) usa-se `T` associado ao DataFrame. Perceba que a transposição é feita apenas em tempo de execução, para usar a estrutura transporta é preciso associar a um novo DataFrame.

# %%
df.T
# Out:
# id         0         1         2      3
# nome   Aline     Pedro    Marina   José
# idade     39        35        28     45
# pet     gato  cachorro  papagaio  peixe

# %% [markdown]
# Uma forma interessante de visualização de um DataFrame é o oferecido pela função `stack()`. Ele apresenta a estrutura em um formato presenta multinível.

# %%
df.stack()
# Out:
# id
# 0   nome        Aline
#     idade          39
#     pet          gato
# 1   nome        Pedro
#     idade          35
#     pet      cachorro
# 2   nome       Marina
#     idade          28
#     pet      papagaio
# 3   nome         José
#     idade          45
#     pet         peixe
# dtype: object

# %% [markdown]
# Se for necessário inserir uma nova coluna no DataFrame, podemos usar a função `insert()`. Passamos por parâmetro a posição onde a coluna deverá ser inserida, o nome da coluna (label) e o valor padrão a ser inserido.

# %%
df.insert(3, "status", "ativo")

# %%
df
# Out:
#       nome  idade       pet status
# id
# 0    Aline     39      gato  ativo
# 1    Pedro     35  cachorro  ativo
# 2   Marina     28  papagaio  ativo
# 3     José     45     peixe  ativo

# %% [markdown]
# Para retirar uma coluna, usa-se `drop()` passando por parâmetro o nome da coluna.

# %%
df.drop("status", axis="columns")
# Out:
#       nome  idade       pet
# id
# 0    Aline     39      gato
# 1    Pedro     35  cachorro
# 2   Marina     28  papagaio
# 3     José     45     peixe

# %% [markdown]
# Caso seja necessário verificar se determinado valor de índica existe, devemos usar `in` buscando na lista de índices `index`:

# %%
6 in df.index
# Out:
# False

# %% [markdown]
# ### 🧩&nbsp;&nbsp;MANIPULAÇÃO DE DADOS

# %% [markdown]
# #### Lendo um arquivo csv

# %% [markdown]
# Na maioria das vezes que vamos trabalhar com a biblioteca Pandas a nossa necessidade será realizar a leitura e manipulação de um conjunto de dados que esteja em um arquivo, banco de dados, API ou qualquer outra fonte externa.
#
# Assim, podemos ler fontes de dados em diferentes formatos e para isso o Pandas oferece uma conjunto de funções.
#
# |Função | Descrição
# |:---:|:---|
# | read_csv() | leitura de dados deliminados no formato CSV - Comma Separated Values (padrão: vírgula)
# | read_table() | leitura de dados delimitados utilizando tabulação ('\t')
# | read_fwf() | leitura de dados delimitados com tamanho fixo de colunas
# | read_clipboard() | leitura de dados da área de transferência
# | read_excel() | leitura de dados tabulares de arquivos Microsoft Excel
# | read_hdf() | leitura de arquivos HDF escritos com o Pandas
# | read_html() | leitura de tabelas que se encontram em documentos HTML
# | read_json() | leitura de dados na representação JSON - Javascript Object Notation
# | read_msgpack() | leitura de dados codificados pelo Pandas no formato binário MessagePack
# | read_pickle() | leitura de objeto armazenado no formato pickle do Python
# | read_sas() | leitura de dados de SAS armazenado em um fos formatos personalizados do sistema SAS
# | read_sql() | leitura do resultado de uma consulta SQL (usando SQLAlchemy) na forma de um DataFrame do Pandas
# | read_stata() | leitura de dados no formato de arquivo Stata
# | read_feather() | leitura de dados no formato de arquivo binário Feather
#
# Certamente uma das mais populares das funções listadas acima é a read_csv() uma vez que o formato Comma Separated Values (CSV) é bastante utilizado para distribuição de datasets.
#
# A seguir a forma simples de leitura de um dataset passando uma URL. Este dataset foi baixado do [repositório de dados abertos da plataforma AirBnb](http://insideairbnb.com/get-the-data) e corresponde a um recorte de dados da plataforma para o Rio de Janeiro.

# %%
df = pd.read_csv("https://alinedecampos.pro.br/etc/datasets/airbnb.csv")

# %% [markdown]
# Além do parâmetro obrigatório que indica o caminho de acesso ao arquivo, temos algumas opções de parâmetros opcionais para tratar questões de interpretação dos dados.
#
# |Função | Descrição
# |:---:|:---|
# | nrows | número de linhas a serem lidas a partir do início do arquivo
# | header | indica o número da linha que contém o cabeçalho (se não houver, deve ser 'None' e o valor padrão é 0)
# | sep | apresenta o(s) caracter(es) de separação dos valores
# | enconding | indica a codificação de texto (indicado UTF-8)
# | thousands | indica o separador de milhares (por exemplo '.'ou ',')
# | na_values | indica por qual valor as colunas NA devem ser substituídas
# | comment | indica o caracter usado para separar comentários
# | skiprows | indica o número das linhaas a serem ignoradas (começando de 0)
# | skip_footer | indica o número de linhas a serem ignoradas no final do arquivo
# | verbose | exibe várias informações de saída do parser, como o número de valores ausentes em colunas não numéricas
# | parse_dates | tenta fazer o parse de dados para DateTime (padrão False)
# | dayfirst | trata datas como em formato internacional (padrão False)
# | date_parser | função usada para parse de datas
# | iterator | devolve um objeto TextParser para ler o arquivo aos poucos
# | chunksize | para iteração é o tamanho das partes do arquivo
# | squeeze | se os dados contem apenas uma coluna devolve uma série
# | index_col | números ou nomes de coluna a serem usados como índice de linhas no resultado
# | converters | dicionário contendo o número ou o nome de colunas mapeadas para funções

# %% [markdown]
# No exemplo a seguir, vamos ler apenas os primeiros 20 registros do arquivo CSV:

# %%
df20 = pd.read_csv("https://alinedecampos.pro.br/etc/datasets/airbnb.csv", nrows=20)
df20
# Out:
#                     id                                               name  \
# 0                17878  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 1   556930647599893392   Venha passar uma pernoite em um veleiro na Urca!
# 2              1174007                  100% Best View In Copa In Suite 2
# 3              8410797  Ipanema(Arpoador) 100mdo Mar/ Jan & Carnaval +Fev
# 4             28053241     Navegar a  Bordo de um Veleiro Francês no Rio!
# 5               249616                Flat at Barra Near by WINDSOR HOTEL
# 6               249842               Copacabana, central e perto da praia
# 7                24480   Nice and cozy near Ipanema Beach, w/ home office
# 8               251701                      LEBLON BEACHFRONT VILLA APT.2
# 9               251868                         Great & comfy studio Copa!
# 10            32539051                       APART-HOTEL VIEIRA SOUTO 510
# 11               25026          Beautiful Modern Decorated Studio in Copa
# ...

# %% [markdown]
# Com a função `info()` podemos apresentar diversos dados estruturais do DataFrame, tais como a quantidade de registros, os nomes das colunas, tipos de dados e uso de memória.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24881 entries, 0 to 24880
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              24881 non-null  int64
#  1   name                            24860 non-null  object
#  2   host_id                         24881 non-null  int64
#  3   host_name                       24764 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   24881 non-null  object
#  6   latitude                        24881 non-null  float64
#  7   longitude                       24881 non-null  float64
#  8   room_type                       24881 non-null  object
#  9   price                           24881 non-null  int64
#  10  minimum_nights                  24881 non-null  int64
#  11  number_of_reviews               24881 non-null  int64
# ...

# %% [markdown]
# O objeto `shape` apresenta as dimensões do DataFrame indicando quantas linhas (registros) e quantos colunas (atributos) este tem:

# %%
df.shape
# Out:
# (24881, 18)

# %% [markdown]
# Podemos ler uma coluna indicando o nome dela no DataFrame:

# %%
df["host_name"]
# Out:
# 0           Matthias
# 1            Andréia
# 2        Thiago Luiz
# 3             Sheila
# 4            Luciano
#             ...
# 24876        Tatiane
# 24877      Elisabeth
# 24878        Claudia
# 24879        Claudia
# 24880        Jumpers
# Name: host_name, Length: 24881, dtype: object

# %% [markdown]
# Podemos usar também a função `filter()` passando uma lista com o nome das colunas desejadas.

# %%
df.filter(["host_name", "room_type", "price"])
# Out:
#          host_name        room_type  price
# 0         Matthias  Entire home/apt    350
# 1          Andréia     Private room    280
# 2      Thiago Luiz     Private room    107
# 3           Sheila     Private room   1000
# 4          Luciano     Private room   1850
# ...            ...              ...    ...
# 24876      Tatiane  Entire home/apt    251
# 24877    Elisabeth  Entire home/apt    440
# 24878      Claudia  Entire home/apt    380
# 24879      Claudia  Entire home/apt    300
# 24880      Jumpers  Entire home/apt    315
#
# [24881 rows x 3 columns]

# %% [markdown]
# Podemos também apresentar os primeiros registros de um DataFrame com `head()`:

# %%
df.head(7)
# Out:
#                    id                                               name  \
# 0               17878  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 1  556930647599893392   Venha passar uma pernoite em um veleiro na Urca!
# 2             1174007                  100% Best View In Copa In Suite 2
# 3             8410797  Ipanema(Arpoador) 100mdo Mar/ Jan & Carnaval +Fev
# 4            28053241     Navegar a  Bordo de um Veleiro Francês no Rio!
# 5              249616                Flat at Barra Near by WINDSOR HOTEL
# 6              249842               Copacabana, central e perto da praia
#
#      host_id    host_name  neighbourhood_group    neighbourhood  latitude  \
# 0      68997     Matthias                  NaN       Copacabana -22.96599
# 1  198206849      Andréia                  NaN             Urca -22.94781
# 2    3962758  Thiago Luiz                  NaN       Copacabana -22.97277
# 3   42038091       Sheila                  NaN          Ipanema -22.98871
# ...

# %% [markdown]
# Ou ainda os últimos registros de um DataFrame com `tail()`:

# %%
df.tail(3)
# Out:
#                        id                                               name  \
# 24878  650011310811912783       Apto em frente à praia com vista lateral mar
# 24879  650020855611122186               Apto com vista deslumbrante na Barra
# 24880  650025403378811576  Jumpinbed - Studio in Copacabana in front of t...
#
#          host_id host_name  neighbourhood_group    neighbourhood   latitude  \
# 24878  238604267   Claudia                  NaN  Barra da Tijuca -23.009351
# 24879  238604267   Claudia                  NaN  Barra da Tijuca -23.008220
# 24880  397106841   Jumpers                  NaN       Copacabana -22.976880
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 24878 -43.344853  Entire home/apt    380               1                  0
# 24879 -43.343700  Entire home/apt    300               2                  0
# 24880 -43.189920  Entire home/apt    315               1                  0
#
# ...

# %% [markdown]
# ####Seleção dos dados

# %% [markdown]
# Em muitos casos teremos datasets com muitas colunas e nem sempre precisaremos utilizar todas elas. Carregar sempre todas as colunas pode ser oneroso em se tratando de processamento e até mesmo organização da nossa prática. Sendo assim, podemos determinar quais são as colunas que devem ser lidas e inseridas no DataFrame.

# %%
dfn = pd.DataFrame(df, columns=["host_name", "name", "neighbourhood", "room_type", "minimum_nights", "price", "number_of_reviews", "reviews_per_month", "last_review"])
display(dfn)
# Out:
#          host_name                                               name  \
# 0         Matthias  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 1          Andréia   Venha passar uma pernoite em um veleiro na Urca!
# 2      Thiago Luiz                  100% Best View In Copa In Suite 2
# 3           Sheila  Ipanema(Arpoador) 100mdo Mar/ Jan & Carnaval +Fev
# 4          Luciano     Navegar a  Bordo de um Veleiro Francês no Rio!
# ...            ...                                                ...
# 24876      Tatiane                   Apartamento encantador no centro
# 24877    Elisabeth               Apartamento encantador em Copacabana
# 24878      Claudia       Apto em frente à praia com vista lateral mar
# 24879      Claudia               Apto com vista deslumbrante na Barra
# 24880      Jumpers  Jumpinbed - Studio in Copacabana in front of t...
#
#          neighbourhood        room_type  minimum_nights  price  \
# ...

# %% [markdown]
# Se necessitarmos criar um DataFrame com apenas algumas linhas, podemos usar a função `iloc` passando em uma lista os índices dos registros necessários. Podemos usar intervalos de valores como `iloc[10:30]` que irá retornar os registros dos índices 10 até 29. Se os registros tiverem índices em valores não numéricos, podemos usar `loc()`.

# %%
df.iloc[[1, 2, 4, 10]]
# Out:
#                     id                                              name  \
# 1   556930647599893392  Venha passar uma pernoite em um veleiro na Urca!
# 2              1174007                 100% Best View In Copa In Suite 2
# 4             28053241    Navegar a  Bordo de um Veleiro Francês no Rio!
# 10            32539051                      APART-HOTEL VIEIRA SOUTO 510
#
#       host_id    host_name  neighbourhood_group neighbourhood  latitude  \
# 1   198206849      Andréia                  NaN          Urca -22.94781
# 2     3962758  Thiago Luiz                  NaN    Copacabana -22.97277
# 4   193860988      Luciano                  NaN          Urca -22.95056
# 10   66213641        Lucia                  NaN       Ipanema -22.98737
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# 1   -43.16351     Private room    280               1                  1
# 2   -43.17966     Private room    107               2                177
# ...

# %% [markdown]
# #### Operações em dados

# %% [markdown]
# Podemos fazer algumas operações em dados como agrupamentos e ordenações.

# %% [markdown]
# #### Agrupamentos

# %% [markdown]
# Usando a função `groupby()` podemos passar a(s) coluna(s) que queremos agrupar. No caso a seguir, estamos contando (função `count()`) os registros da coluna `name` agrupando pela coluna `neighbourhood`:

# %%
dfn.groupby("neighbourhood")["name"].count()
# Out:
# neighbourhood
# Abolição              4
# Acari                 1
# Alto da Boa Vista    36
# Anchieta              2
# Andaraí              39
#                      ..
# Vila Militar          2
# Vila Valqueire       15
# Vila da Penha         8
# Zumbi                 1
# Água Santa            3
# Name: name, Length: 153, dtype: int64

# %% [markdown]
# Caso seja mais de um valor, temos que passar como listas:

# %%
dfn.groupby(["neighbourhood", "room_type"])["name"].count()
# Out:
# neighbourhood      room_type
# Abolição           Entire home/apt     3
#                    Shared room         1
# Acari              Entire home/apt     1
# Alto da Boa Vista  Entire home/apt    28
#                    Private room        7
#                                       ..
# Vila da Penha      Private room        5
#                    Shared room         2
# Zumbi              Entire home/apt     1
# Água Santa         Entire home/apt     2
#                    Private room        1
# Name: name, Length: 371, dtype: int64

# %% [markdown]
# Se quiser exibir apenas os registros de um determinado grupo, pode-se usar a função `get_group()` passando por parâmetro o grupo desejado.

# %%
dfn.groupby("neighbourhood").get_group("Copacabana")
# Out:
#            host_name                                               name  \
# 0           Matthias  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 2        Thiago Luiz                  100% Best View In Copa In Suite 2
# 6              Sonia               Copacabana, central e perto da praia
# 9             Helena                         Great & comfy studio Copa!
# 11           Viviane          Beautiful Modern Decorated Studio in Copa
# ...              ...                                                ...
# 24833         Aretha   Ótima suíte em Copacabana, a uma quadra da praia
# 24835  Rafaele Bispo                      Ocean front Copacabana post 5
# 24858        Roberto               Apartamento vista mar em Copacabana.
# 24877      Elisabeth               Apartamento encantador em Copacabana
# 24880        Jumpers  Jumpinbed - Studio in Copacabana in front of t...
#
#       neighbourhood        room_type  minimum_nights  price  \
# ...

# %% [markdown]
# Temos alguns objetos implícitos com informações que podem ser úteis sobre o agrupamento. O objeto `groups` mostra um dicionário de dados completo com todos os índices para cada registro de agrupamento realizado.

# %%
dfn.groupby("neighbourhood")["name"].groups
# Out:
# {'Abolição': [5226, 6540, 6863, 9166], 'Acari': [14023], 'Alto da Boa Vista': [383, 519, 1486, 2078, 2122, 3104, 5289, 6127, 6265, 6868, 6880, 6994, 8206, 8762, 10010, 10897, 12137, 12525, 12758, 13733, 14560, 15944, 16406, 17430, 17826, 19059, 19355, 21048, 22227, 22368, 22428, 22575, 22810, 23921, 24599, 24873], 'Anchieta': [6047, 14762], 'Andaraí': [869, 1018, 1626, 1689, 1887, 2228, 3611, 3789, 5909, 6784, 6816, 7070, 7144, 7259, 8122, 8427, 9900, 10180, 10181, 11812, 11963, 12031, 12076, 12107, 14042, 14921, 14954, 14983, 15929, 16228, 17678, 18183, 20490, 20573, 21429, 21512, 21682, 23169, 23244], 'Anil': [572, 1431, 2732, 3558, 4218, 4792, 5457, 5645, 6212, 6347, 6473, 6690, 7098, 7245, 7486, 8088, 10501, 11107, 11457, 12934, 13045, 13604, 13652, 14758, 15522, 17552, 17609, 18572, 18653, 19985, 20048, 20971, 21482, 21527, 21849, 22760, 23119, 23837, 23860, 23915, 24016, 24051, 24131, 24256, 24257, 24267, 24346, 24361, 24796], 'Bancários': [6029, 6033, 17534, 23398, 24439], 'Ba
# ...

# %% [markdown]
# Já o objeto `indices` apresenta um dicionário com arrays de índices para cada valor gerado pelo agrupamento.

# %%
dfn.groupby("neighbourhood")["name"].indices
# Out:
# {'Abolição': array([5226, 6540, 6863, 9166]),
#  'Acari': array([14023]),
#  'Alto da Boa Vista': array([  383,   519,  1486,  2078,  2122,  3104,  5289,  6127,  6265,
#          6868,  6880,  6994,  8206,  8762, 10010, 10897, 12137, 12525,
#         12758, 13733, 14560, 15944, 16406, 17430, 17826, 19059, 19355,
#         21048, 22227, 22368, 22428, 22575, 22810, 23921, 24599, 24873]),
#  'Anchieta': array([ 6047, 14762]),
#  'Andaraí': array([  869,  1018,  1626,  1689,  1887,  2228,  3611,  3789,  5909,
#          6784,  6816,  7070,  7144,  7259,  8122,  8427,  9900, 10180,
#         10181, 11812, 11963, 12031, 12076, 12107, 14042, 14921, 14954,
#         14983, 15929, 16228, 17678, 18183, 20490, 20573, 21429, 21512,
#         21682, 23169, 23244]),
#  'Anil': array([  572,  1431,  2732,  3558,  4218,  4792,  5457,  5645,  6212,
#          6347,  6473,  6690,  7098,  7245,  7486,  8088, 10501, 11107,
#         11457, 12934, 13045, 13604, 13652, 14758, 15522, 17552, 17609,
# ...

# %% [markdown]
# Por fim, `ngroups` apresenta a quantidade de grupos criados pelo agrupamento.

# %%
dfn.groupby("neighbourhood")["name"].ngroups
# Out:
# 153

# %% [markdown]
# Em caso da necessidade de agregação de mais de uma operação no agrupamento, podemos usar a função `aggregate` indicando em uma lista quais operações devem ser realizadas:

# %%
dfn.groupby("neighbourhood")["number_of_reviews"].aggregate(["count", "sum"])
# Out:
#                    count  sum
# neighbourhood
# Abolição               4    0
# Acari                  1    0
# Alto da Boa Vista     36  445
# Anchieta               2    0
# Andaraí               39  179
# ...                  ...  ...
# Vila Militar           2   97
# Vila Valqueire        15  162
# Vila da Penha          8   20
# Zumbi                  1    3
# Água Santa             3    1
#
# [153 rows x 2 columns]

# %% [markdown]
# #### Filtragem de dados

# %% [markdown]
# Podemos criar consultas de uma maneira muito semelhante ao que realizamos em consultas em bases de dados relacionais. A forma mais simples é criando o filtro dentro do DataFrame. No exemplo a seguir estamos selecionando todos os registros que o preço esteja entre 200 e 500 reais"

# %%
dfn[ (dfn["price"] >= 200) & (dfn["price"] <= 500) ]
# Out:
#             host_name                                               name  \
# 0            Matthias  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 1             Andréia   Venha passar uma pernoite em um veleiro na Urca!
# 15              Jorge   Great Dbl Bed/Pvt Bath, Leme, 1 min from the Sea
# 16       Ana Cristina                     APTO BOTAFOGO - BEM LOCALIZADO
# 20     Valerie & Alex                 Duplex in BARRA  w/private terrace
# ...               ...                                                ...
# 24876         Tatiane                   Apartamento encantador no centro
# 24877       Elisabeth               Apartamento encantador em Copacabana
# 24878         Claudia       Apto em frente à praia com vista lateral mar
# 24879         Claudia               Apto com vista deslumbrante na Barra
# 24880         Jumpers  Jumpinbed - Studio in Copacabana in front of t...
#
#          neighbourhood        room_type  minimum_nights  price  \
# ...

# %% [markdown]
# Aqui uma consulta com mais critérios e o uso de operadores relacionais e lógicos. Importante perceber que para AND devemos usar o símvolo `&` e para OR o símbolo `|`. Neste caso estamos filtrando os registros que tenham bairro "Copacabana" E com preço maior ou igual a 1000 E que a quantidade mínima de noites seja 4 OU que tenha mais do que 10 reviews.

# %%
dfn[
    (dfn["neighbourhood"] == "Copacabana") &
    (dfn["price"] >= 1000) &
    ( ( dfn["minimum_nights"] == 4) | (dfn["number_of_reviews"] > 10) )
]
# Out:
#         host_name                                               name  \
# 99         Renata   Beautiful Newly Renovated Studio in Copacabana !
# 168      Wolfgang                Penthouse Oceanview Copacab/Ipanema
# 179          Yann  Stunning penthouse with ocean view and panoram...
# 339        Gilles              Copacabana Penthouse Xavier - 4 rooms
# 388        Rubens         3 Bedrooms in the best point of Copacabana
# ...           ...                                                ...
# 20846     Gustavo                      Apartamento Elegante & Design
# 21014  Pineapples  CaviRio RD1003 | 2-bedroom apartment overlooki...
# 21098       Maria     Flat bem localizado entre Ipanema e Copacabana
# 21549     Luciano                      IPA-COPA APARTAMENTO COMPLETO
# 24179       David  Apartamento de luxo com maravilhosa vista da p...
#
#       neighbourhood        room_type  minimum_nights  price  \
# 99       Copacabana  Entire home/apt               4   2766
# ...

# %% [markdown]
# Podemos usar a função `isin()` para avaliar se um valor consta no DataFrame. O retorno será sempre verdadeiro ou falso. Ao inserimos como filtro do DataFrame teremos o retorno das linhas que atendem ao critério.

# %%
dfn[dfn["host_name"].isin(["Claudia", "David"])]
# Out:
#       host_name                                               name  \
# 27        David  Djalma Ocean View Studio with Amazing Views #100A
# 60        David                  Beach and Mountain beauty in Rio!
# 308     Claudia                     Amazing View Apt in Copacabana
# 420     Claudia                       few steps from Ipanema beach
# 430     Claudia                    Duplex penthouse near the beach
# ...         ...                                                ...
# 24547   Claudia                                  Copacabana Studio
# 24611   Claudia   Casa inteira na Ilha da Gigoia (Barra da Tijuca)
# 24872   Claudia                         Apto aconchegante na Barra
# 24878   Claudia       Apto em frente à praia com vista lateral mar
# 24879   Claudia               Apto com vista deslumbrante na Barra
#
#          neighbourhood        room_type  minimum_nights  price  \
# 27          Copacabana  Entire home/apt               3    200
# ...

# %% [markdown]
# Com a função `contains()` também podemos usar uma estratégia semelhante ao "LIKE" das consultas em SQL nos bancos de dados relacionais. Assim, buscaremos por um termo no conteúdo de determinada coluna do DataFrame. O atributo `case=False` faz com que seja ignorada a diferença entre maiúsculas e minúsculas.

# %%
dfn[dfn["name"].str.contains("Piscina", case=False).fillna(False)]
# Out:
#             host_name                                               name  \
# 148         Alexander         LUX RIO 06 - Flat Frente praia com piscina
# 233           Ricardo   Itaguaí Flat, garagem, piscina, Spa, academia...
# 236             Darke  Apartamento 2 quartos, piscina, academia, Garagem
# 788    Carlos Eduardo                Casa 4 suítes,piscina,churrasqueira
# 1190        Guilherme                          Casa especial com piscina
# ...               ...                                                ...
# 24785       Elizabeth      APTO GARDEN COM PISCINA EM CONDOMÍNIO DE LUXO
# 24796         Gustavo     Casa em condomínio com piscina e churrasqueira
# 24817         Eduardo  CASA AC FUTEBOL PISCINA SAUNA CHURR E PIZZA LENHA
# 24870           Cairo   3Qtos c/ Vista Cinematográfica, Piscina, 400Mbps
# 24871       Georgiana  Pousada da Gigóia Barra da Tijuca. Piscina e c...
#
#                   neighbourhood        room_type  minimum_nights  price  \
# ...

# %% [markdown]
# Para buscas simples com operadores relacionais e lógicos podemos usar também a função `query()`

# %%
# dfn[ (dfn["neighbourhood"] == "Copacabana") & (dfn["price"] >=500) ]
dfn.query("neighbourhood == 'Copacabana' & price <= 500")
# Out:
#            host_name                                               name  \
# 0           Matthias  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 2        Thiago Luiz                  100% Best View In Copa In Suite 2
# 6              Sonia               Copacabana, central e perto da praia
# 9             Helena                         Great & comfy studio Copa!
# 11           Viviane          Beautiful Modern Decorated Studio in Copa
# ...              ...                                                ...
# 24833         Aretha   Ótima suíte em Copacabana, a uma quadra da praia
# 24835  Rafaele Bispo                      Ocean front Copacabana post 5
# 24858        Roberto               Apartamento vista mar em Copacabana.
# 24877      Elisabeth               Apartamento encantador em Copacabana
# 24880        Jumpers  Jumpinbed - Studio in Copacabana in front of t...
#
#       neighbourhood        room_type  minimum_nights  price  \
# ...

# %%
dfn.query("neighbourhood == 'Copacabana' & price <= 500")
# Out:
#            host_name                                               name  \
# 0           Matthias  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 2        Thiago Luiz                  100% Best View In Copa In Suite 2
# 6              Sonia               Copacabana, central e perto da praia
# 9             Helena                         Great & comfy studio Copa!
# 11           Viviane          Beautiful Modern Decorated Studio in Copa
# ...              ...                                                ...
# 24833         Aretha   Ótima suíte em Copacabana, a uma quadra da praia
# 24835  Rafaele Bispo                      Ocean front Copacabana post 5
# 24858        Roberto               Apartamento vista mar em Copacabana.
# 24877      Elisabeth               Apartamento encantador em Copacabana
# 24880        Jumpers  Jumpinbed - Studio in Copacabana in front of t...
#
#       neighbourhood        room_type  minimum_nights  price  \
# ...

# %% [markdown]
# #### Ordenação de dados

# %% [markdown]
# Para ordenação dos dados, podemos usar a função `sort_values()` passando como parâmetro o rótulo da coluna que guiará a sequência.

# %%
dfn.sort_values("price")
# Out:
#               host_name                                               name  \
# 15468        Rio Design                                   Rio Design Hotel
# 16174            Selina                                  Selina Copacabana
# 15469             Ra-Iz                     Belga Hotel e Restaurante Ltda
# 15553  Américas Granada                             Americas Granada Hotel
# 15589         Augusto'S                            Augusto's Riocopa Hotel
# ...                 ...                                                ...
# 19608         Alexandre                                Não está disponivel
# 13478             Loris  B&B Linda House - Double bedroom between Copac...
# 17748            Thiago  Suítes e quartos no Itanhangá-temporada ou mensal
# 20117             Vitor  apartamento lindo em rua sem saída pertinho praia
# 6460          Elizabeth               Temporary rentals for Brazilian Cup.
#
#        neighbourhood        room_type  minimum_nights   price  \
# ...

# %% [markdown]
# Por padrão os valores são apresentados em ordem crescente, assim se quiseremos que seja apresentado em ordem decrescente temos que usar o parâmetro `ascending=False`.

# %%
dfn.sort_values("price", ascending=False)
# Out:
#               host_name                                               name  \
# 6460          Elizabeth               Temporary rentals for Brazilian Cup.
# 20117             Vitor  apartamento lindo em rua sem saída pertinho praia
# 17748            Thiago  Suítes e quartos no Itanhangá-temporada ou mensal
# 13478             Loris  B&B Linda House - Double bedroom between Copac...
# 19608         Alexandre                                Não está disponivel
# ...                 ...                                                ...
# 16174            Selina                                  Selina Copacabana
# 15589         Augusto'S                            Augusto's Riocopa Hotel
# 15533    Américas Barra                     Américas Barra Hotel & Eventos
# 15534          Américas                          Américas Copacabana Hotel
# 15553  Américas Granada                             Americas Granada Hotel
#
#          neighbourhood        room_type  minimum_nights   price  \
# ...

# %% [markdown]
# Também podemos fazer a ordenação pelos índices dos registros.

# %%
# Out:
#         host_name                                               name  \
# 12629      Amaury          Ótimo apto em Copacabana ao lado do Metro
# 4603      Marilda  Quarto para meninas ou amigas Para Réveillon 2020
# 17300    Caroline                        Apartamento quadra da praia
# 22474     Vanessa      Apartamento amplo e encantador em Copacabana!
# 2597      Vanessa   Charming loft between copacabana n ipanema beach
# ...           ...                                                ...
# 23767       Pablo    Quarto compartilhado a 3 min da praia. posto 3.
# 15534    Américas                          Américas Copacabana Hotel
# 15468  Rio Design                                   Rio Design Hotel
# 15589   Augusto'S                            Augusto's Riocopa Hotel
# 16174      Selina                                  Selina Copacabana
#
#       neighbourhood        room_type  minimum_nights  price  \
# 12629    Copacabana  Entire home/apt               5    500
# ...

# %% [markdown]
# Podemos usar quantas colunas forem necessárias para estabelecer a ordenação, basta que seja indicado em formato de lista como parâmetro da função `sort_values()`.

# %%
dfn.query("neighbourhood == 'Copacabana' & price <= 500").sort_values(["minimum_nights", "price"])
# Out:
#           host_name                                             name  \
# 15468    Rio Design                                 Rio Design Hotel
# 15589     Augusto'S                          Augusto's Riocopa Hotel
# 16174        Selina                                Selina Copacabana
# 23767         Pablo  Quarto compartilhado a 3 min da praia. posto 3.
# 12208  Jose Ricardo          RICARDO CASA PORTO SEGURO TUR COM WI-FI
# ...             ...                                              ...
# 17926    Christiane         Apartamento aconchegante, a 50m da praia
# 2205         Melina                 Modern & sunny apt in Copacabana
# 9275         Márcia           Estúdio Copacabana Princesinha do Mar.
# 4327        Eduardo                      Quarto e Sala em Copacabana
# 14521        Romero                      Copacabana quadra da praia!
#
#       neighbourhood        room_type  minimum_nights  price  \
# 15468    Copacabana       Hotel room               1      0
# ...

# %% [markdown]
# #### Tratamento de dados

# %% [markdown]
# Para efetuar operações de tratamento de dados nos DataFrames a biblioteca Pandas apresenta algumas funções.
#
# Por exemplo, a função `drop_duplicates()` que remove linhas com valores duplicados.

# %%
dfn.drop_duplicates()
# Out:
#          host_name                                               name  \
# 0         Matthias  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 1          Andréia   Venha passar uma pernoite em um veleiro na Urca!
# 2      Thiago Luiz                  100% Best View In Copa In Suite 2
# 3           Sheila  Ipanema(Arpoador) 100mdo Mar/ Jan & Carnaval +Fev
# 4          Luciano     Navegar a  Bordo de um Veleiro Francês no Rio!
# ...            ...                                                ...
# 24876      Tatiane                   Apartamento encantador no centro
# 24877    Elisabeth               Apartamento encantador em Copacabana
# 24878      Claudia       Apto em frente à praia com vista lateral mar
# 24879      Claudia               Apto com vista deslumbrante na Barra
# 24880      Jumpers  Jumpinbed - Studio in Copacabana in front of t...
#
#          neighbourhood        room_type  minimum_nights  price  \
# ...

# %% [markdown]
# A função `isnull()` ou `isna()` que verifica se o registro contém valores fantantes (missing values).

# %%
dfn.isnull()
# Out:
#        host_name   name  neighbourhood  room_type  minimum_nights  price  \
# 0          False  False          False      False           False  False
# 1          False  False          False      False           False  False
# 2          False  False          False      False           False  False
# 3          False  False          False      False           False  False
# 4          False  False          False      False           False  False
# ...          ...    ...            ...        ...             ...    ...
# 24876      False  False          False      False           False  False
# 24877      False  False          False      False           False  False
# 24878      False  False          False      False           False  False
# 24879      False  False          False      False           False  False
# 24880      False  False          False      False           False  False
#
#        number_of_reviews  reviews_per_month  last_review
# ...

# %% [markdown]
# Já a função `dropna()` remove os registros com valores faltantes. Essa operação é realizada em tempo de execução, por isso para registrar seus efeitos no DataFrame deve-se usar o parâmetro `inplace=True` ou então associar a um novo DataFrame.

# %%
dflimpo = dfn.dropna()
display(dflimpo)
# Out:
#          host_name                                               name  \
# 0         Matthias  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 1          Andréia   Venha passar uma pernoite em um veleiro na Urca!
# 2      Thiago Luiz                  100% Best View In Copa In Suite 2
# 3           Sheila  Ipanema(Arpoador) 100mdo Mar/ Jan & Carnaval +Fev
# 5             Malí                Flat at Barra Near by WINDSOR HOTEL
# ...            ...                                                ...
# 24862        Neusa                                  Vidiga Ocean View
# 24865        Maria  Apartamento frente mar para a praia de Ipanema...
# 24866    Francisco                        Praia  Barra de Guaratiba 4
# 24867     Fernando                 Ipanema Residence with ocean view!
# 24877    Elisabeth               Apartamento encantador em Copacabana
#
#             neighbourhood        room_type  minimum_nights  price  \
# ...

# %% [markdown]
# Pode também preencher os dados faltantes com o valor desejado usando a função `fillna()`:

# %%
dfn = dfn.fillna("NULL")
display(dfn)
# Out:
#          host_name                                               name  \
# 0         Matthias  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 1          Andréia   Venha passar uma pernoite em um veleiro na Urca!
# 2      Thiago Luiz                  100% Best View In Copa In Suite 2
# 3           Sheila  Ipanema(Arpoador) 100mdo Mar/ Jan & Carnaval +Fev
# 4          Luciano     Navegar a  Bordo de um Veleiro Francês no Rio!
# ...            ...                                                ...
# 24876      Tatiane                   Apartamento encantador no centro
# 24877    Elisabeth               Apartamento encantador em Copacabana
# 24878      Claudia       Apto em frente à praia com vista lateral mar
# 24879      Claudia               Apto com vista deslumbrante na Barra
# 24880      Jumpers  Jumpinbed - Studio in Copacabana in front of t...
#
#          neighbourhood        room_type  minimum_nights  price  \
# ...

# %% [markdown]
# # 📚&nbsp;&nbsp;REFERÊNCIAS UTILIZADAS

# %% [markdown]
# [🔗](https://books.google.com.br/books?id=Oj5FDwAAQBAJ&printsec=frontcover&hl=pt-BR&source=gbs_ge_summary_r&cad=0#v=onepage&q&f=false) &nbsp;
# MCKINNEY, Wes. **Python Para Análise de Dados: tratamento de dados com Pandas, NumPy e IPython**. Novatec Editora, 2018.
#
# [🔗](https://pandas.pydata.org/docs/) &nbsp;
# PANDAR OFFICIAL WEBSITE. **Pandas Documentation.** Version: 1.5.0, 2022.

# %% [markdown]
# #🔎&nbsp;&nbsp;CONTEÚDOS COMPLEMENTARES

# %% [markdown]
# #### **Links interessantes**
#
# [🔗](https://www.geeksforgeeks.org/pandas-tutorial/) **GeeksforGeeks Pandas Tutorial:** um ótimo tutorial bastante detalhado e com exemplos de aplicação da biblioteca.
#
# [🔗](https://www.kaggle.com/learn/pandas) **Kaggle Pandas:** tutorial da biblioteca Pandas feito pela Kaggle.
